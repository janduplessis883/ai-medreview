# %%
import pandas as pd
import os

# Get current directory
current_dir = os.getcwd()
print(f"Current directory: {current_dir}")

try:
    # Read data from CSV file
    data = pd.read_csv('data.csv')
    
    print("Data loaded successfully.")
    
    if len(data) == 0:
        print("Warning: The data file is empty or contains no valid rows.")
        
    # Display the first few rows of the DataFrame
    display(data.head())
    
except FileNotFoundError:
    print(f"Error: File 'data.csv' not found in current directory. Please check the file path.")
except Exception as e:
    print(f"An error occurred while loading data: {str(e)}")
finally:
    print("Processing completed.")
# Out:
# Current directory: /Users/janduplessis/code/janduplessis883/ai-medreview/notebooks
# Data loaded successfully.
#                   time     rating  \
# 0  2024-01-01 10:51:00  Very good
# 1  2024-01-01 15:20:00  Very good
# 2  2024-01-01 17:47:00  Very good
# 3  2024-01-02 07:58:00       Good
# 4  2024-01-02 10:44:00  Very good
#
#                                            free_text do_better  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  PERSON was amazing kind and helpful The recept...       NaN
# 4                                                NaN       NaN
#
#                     surgery                  pcn sentiment_free_text  \
# 0  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# 1  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# ...

# %%
import pandas as pd
import os

# Get current directory
current_dir = os.getcwd()
print(f"Current directory: {current_dir}")

try:
    # Read data from CSV file
    data = pd.read_csv('data.csv')
    
    print("Data loaded successfully.")
    
    if len(data) == 0:
        print("Warning: The data file is empty or contains no valid rows.")
        
    # Display the first few rows of the DataFrame
    display(data.head())
    
except FileNotFoundError:
    print(f"Error: File 'data.csv' not found in current directory. Please check the file path.")
except Exception as e:
    print(f"An error occurred while loading data: {str(e)}")
finally:
    print("Processing completed.")
# Out:
# Current directory: /Users/janduplessis/code/janduplessis883/ai-medreview/notebooks
# Data loaded successfully.
#                   time     rating  \
# 0  2024-01-01 10:51:00  Very good
# 1  2024-01-01 15:20:00  Very good
# 2  2024-01-01 17:47:00  Very good
# 3  2024-01-02 07:58:00       Good
# 4  2024-01-02 10:44:00  Very good
#
#                                            free_text do_better  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  PERSON was amazing kind and helpful The recept...       NaN
# 4                                                NaN       NaN
#
#                     surgery                  pcn sentiment_free_text  \
# 0  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# 1  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# ...
