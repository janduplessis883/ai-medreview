# %%
import pandas as pd
from darts import TimeSeries
from darts.models import NBEATSModel
from darts.metrics import smape, mae, rmse, mape
import tqdm as tqdm

# %%
df = pd.read_csv('ts_pred2.csv')

# %%
df.head()
# Out:
#     YearMonth  appointment_availability  online_systems  blood_tests  \
# 0  2024-01-31                    -0.342          -0.723       -0.730
# 1  2024-02-29                    -0.373          -0.248       -0.903
# 2  2024-03-31                    -0.382          -0.453       -0.369
# 3  2024-04-30                    -0.361          -0.424       -0.794
# 4  2024-05-31                    -0.258          -0.472       -0.747
#
#    getting_through_on_phone  excellent_clinical_care  follow-up  noise  \
# 0                    -0.707                    0.590     -0.845  0.145
# 1                    -0.662                    0.677     -0.287 -0.530
# 2                    -0.751                    0.822     -0.148 -0.372
# 3                    -0.779                    0.633     -0.205 -0.496
# 4                    -0.364                    0.714     -0.287 -0.495
#
#    overall_excellent  prescriptions  reception_staff_friendly  \
# 0              0.816         -0.738                     0.948
# 1              0.856         -0.676                     0.798
# 2              0.898         -0.246                     0.761
# 3              0.885         -0.623                     0.788
# 4              0.818         -0.285                     0.744
#
#    reception_staff_rude  rushed_consultation  staff_kindness  \
# 0                   NaN               -0.525           0.712
# 1                -0.741               -0.724           0.747
# 2                -0.441               -0.756           0.721
# 3                -0.694               -0.671           0.770
# 4                -0.569               -0.470           0.543
#
#    staff_professionalism  telehealth  treatment_quality  vaccinations  \
# 0                  0.728      -0.556              0.081           NaN
# 1                  0.143      -0.371              0.280        -0.282
# 2                  0.300      -0.260              0.311         0.054
# 3                  0.213      -0.313              0.220        -0.218
# 4                  0.189      -0.294              0.343        -0.643
#
#    waiting_time
# 0        -0.731
# 1        -0.693
# 2        -0.904
# 3        -0.670
# 4        -0.581

# %%
df_one = df[['YearMonth', 'online_systems']].copy()

# %%
df_one["YearMonth"] = pd.to_datetime(df_one["YearMonth"])
df_one = df_one.sort_values(by="YearMonth")

# %%
series = TimeSeries.from_dataframe(df_one,
                                   time_col="YearMonth",
                                   value_cols="online_systems",
                                   fill_missing_dates=True,
                                   freq=None)

# %%
series
# Out:
#             online_systems
# YearMonth
# 2024-01-31          -0.723
# 2024-02-29          -0.248
# 2024-03-31          -0.453
# 2024-04-30          -0.424
# 2024-05-31          -0.472
# ...                    ...
# 2025-08-31          -0.081
# 2025-09-30          -0.221
# 2025-10-31          -0.122
# 2025-11-30           0.134
# 2025-12-31          -0.377
#
# shape: (24, 1, 1), freq: ME, size: 192.00 B

# %%
validation_length = 3
train_series, val_series = series[:-validation_length], series[-validation_length:]
# Out:
#             online_systems
# YearMonth
# 2025-10-31          -0.122
# 2025-11-30           0.134
# 2025-12-31          -0.377
#
# shape: (3, 1, 1), freq: ME, size: 24.00 B

# %%
input_chunk_length=6,
output_chunk_length=2,
n_epochs=40

pl_trainer_kwargs = {"accelerator": "cpu"}
optimizer_kwargs = {'lr': 1e-3}

model = NBEATSModel(
    input_chunk_length=input_chunk_length,
    output_chunk_length=output_chunk_length,
    output_chunk_shift=0,
    n_epochs=n_epochs,
    random_state=42,
    force_reset=True,
    save_checkpoints=False,
    pl_trainer_kwargs=pl_trainer_kwargs,
    optimizer_kwargs=optimizer_kwargs,
    # Default NBEATS generic architecture parameters
    num_stacks=30,
    num_blocks=1,
    num_layers=4,
    layer_widths=256,
    activation='ReLU',
    batch_size=32,
)
# Train the model on the scaled training data.
model.fit(train_series, verbose=True)


# 4. Make Predictions on Validation Set and Evaluate
print("Evaluating model on the validation set...")
val_predictions = model.predict(n=len(val_series))
# IMPORTANT: Inverse transform predictions to get them back to the original scale.
# val_predictions = scaler.inverse_transform(val_predictions_scaled)

# Initialize metrics to handle cases with no positive validation data
nbeats_smape, nbeats_mae, nbeats_rmse, nbeats_mape = [np.nan] * 4

# Calculate sMAPE on non-zero actuals to avoid division-by-zero errors.
# *** FIX: Convert to pandas Series to perform boolean filtering, as Darts TimeSeries doesn't support it. ***
val_series_pd = val_series.to_series()
val_series_non_zero_pd = val_series_pd[val_series_pd > 0]

if not val_series_non_zero_pd.empty:
    # Convert back to a TimeSeries for Darts metrics and functions
    val_series_non_zero = TimeSeries.from_series(val_series_non_zero_pd)
    val_predictions_filtered = val_predictions.slice_intersect(val_series_non_zero)

    # Calculate evaluation metrics
    nbeats_smape = smape(val_series_non_zero, val_predictions_filtered)
    nbeats_mae = mae(val_series_non_zero, val_predictions_filtered)
    nbeats_rmse = rmse(val_series_non_zero, val_predictions_filtered)
    nbeats_mape = mape(val_series_non_zero, val_predictions_filtered)

    print(f"-> NBEATS sMAPE on validation set (non-zero actuals): {nbeats_smape:.2f}%")
    print(f"-> NBEATS MAPE on validation set (non-zero actuals): {nbeats_mape:.2f}%")
    print(f"-> NBEATS MAE on validation set: {nbeats_mae:.2f}")
    print(f"-> NBEATS RMSE on validation set: {nbeats_rmse:.2f}")
else:
    print("-> No positive actuals in validation set for evaluation.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 27
#       8 model = NBEATSModel(
#       9     input_chunk_length=input_chunk_length,
#      10     output_chunk_length=output_chunk_length,
#    (...)     24     batch_size=32,
#      25 )
#      26 # Train the model on the scaled training data.
# ---> 27 model.fit(train_series, verbose=True)
#      30 # 4. Make Predictions on Validation Set and Evaluate
#      31 print("Evaluating model on the validation set...")
#
# File ~/.pyenv/versions/3.13.9/envs/aimed/lib/python3.13/site-packages/darts/utils/torch.py:94, in random_method.<locals>.decorator(self, *args, **kwargs)
#      92 with fork_rng():
#      93     manual_seed(random_instance.randint(0, high=MAX_TORCH_SEED_VALUE))
# ---> 94     return decorated(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.13.9/envs/aimed/lib/python3.13/site-packages/darts/models/forecasting/torch_forecasting_model.py:934, in TorchForecastingModel.fit(self, series, past_covariates, future_covariates, val_series, val_past_covariates, val_future_covariates, trainer, verbose, epochs, max_samples_per_ts, dataloader_kwargs, sample_weight, val_sample_weight, stride, load_best)
#     821 @random_method
#     822 def fit(
#     823     self,
#    (...)    840     load_best: bool = False,
#     841 ) -> "TorchForecastingModel":
#     842     """Fit/train the model on one or multiple series.
#     843
#     844     This method wraps around :func:`fit_from_dataset()`, constructing a default training
#    (...)    925         Fitted model.
#     926     """
#     927     (
#     928         (
#     929             series,
#     930             past_covariates,
#     931             future_covariates,
#     932         ),
#     933         params,
# --> 934     ) = self._setup_for_fit_from_dataset(
#     935         series=series,
#     936         past_covariates=past_covariates,
#     937         future_covariates=future_covariates,
#     938         sample_weight=sample_weight,
#     939         stride=stride,
#     940         val_series=val_series,
#     941         val_past_covariates=val_past_covariates,
#     942         val_future_covariates=val_future_covariates,
#     943         val_sample_weight=val_sample_weight,
#     944         trainer=trainer,
#     945         verbose=verbose,
#     946         epochs=epochs,
#     947         max_samples_per_ts=max_samples_per_ts,
#     948         dataloader_kwargs=dataloader_kwargs,
#     949         load_best=load_best,
#     950     )
#     951     # call super fit only if user is actually fitting the model
#     952     super().fit(
#     953         series=seq2series(series),
#     954         past_covariates=seq2series(past_covariates),
#     955         future_covariates=seq2series(future_covariates),
#     956         verbose=verbose,
#     957     )
#
# File ~/.pyenv/versions/3.13.9/envs/aimed/lib/python3.13/site-packages/darts/models/forecasting/torch_forecasting_model.py:1010, in TorchForecastingModel._setup_for_fit_from_dataset(self, series, past_covariates, future_covariates, sample_weight, stride, val_series, val_past_covariates, val_future_covariates, val_sample_weight, trainer, verbose, epochs, max_samples_per_ts, dataloader_kwargs, load_best)
#    1007 if not isinstance(val_sample_weight, str):
#    1008     val_sample_weight = series2seq(val_sample_weight)
# -> 1010 self.encoders = self.initialize_encoders()
#    1011 if self.encoders.encoding_available:
#    1012     past_covariates, future_covariates = self.generate_fit_encodings(
#    1013         series=series,
#    1014         past_covariates=past_covariates,
#    1015         future_covariates=future_covariates,
#    1016     )
#
# File ~/.pyenv/versions/3.13.9/envs/aimed/lib/python3.13/site-packages/darts/models/forecasting/forecasting_model.py:2382, in ForecastingModel.initialize_encoders(self, default)
#    2372 if default:
#    2373     return SequentialEncoder(add_encoders={})
#    2375 (
#    2376     input_chunk_length,
#    2377     output_chunk_length,
#    2378     takes_past_covariates,
#    2379     takes_future_covariates,
#    2380     lags_past_covariates,
#    2381     lags_future_covariates,
# -> 2382 ) = self._model_encoder_settings
#    2384 return SequentialEncoder(
#    2385     add_encoders=self.add_encoders,
#    2386     input_chunk_length=input_chunk_length,
#    (...)   2391     takes_future_covariates=takes_future_covariates,
#    2392 )
#
# File ~/.pyenv/versions/3.13.9/envs/aimed/lib/python3.13/site-packages/darts/models/forecasting/torch_forecasting_model.py:2552, in TorchForecastingModel._model_encoder_settings(self)
#    2546 @property
#    2547 def _model_encoder_settings(
#    2548     self,
#    2549 ) -> tuple[int, int, bool, bool, Optional[list[int]], Optional[list[int]]]:
#    2550     return (
#    2551         self.input_chunk_length,
# -> 2552         self.output_chunk_length + self.output_chunk_shift,
#    2553         self.supports_past_covariates,
#    2554         self.supports_future_covariates,
#    2555         None,
#    2556         None,
#    2557     )
#
# TypeError: can only concatenate tuple (not "int") to tuple
