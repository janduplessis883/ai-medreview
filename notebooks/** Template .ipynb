# %% [markdown]
# <div class='status' style='background-color: #183a4b; color: white; padding-top: 4px; padding-bottom: 4px; padding-left: 20px; padding-right: 20px; border-radius: 10px; font-family: Arial, sans-serif; font-size: 26px; display: inline-block; text-align: center; box-shadow: 0px 3px 4px rgba(0, 0, 0, 0.5);'><b>** TEMPLATE</B> - Start here</div>

# %% [markdown]
# ## Loading Libraries

# %%
# Importing default Libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import datetime
import os
from tqdm import tqdm

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# Hi-resolution Plots and Matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Set the maximum number of rows and columns to be displayed
warnings.filterwarnings("ignore")

# "magic commands" to enable autoreload of your imported packages
# %load_ext autoreload
# %autoreload 2

# %%
from jan883_codebase.data_preprocessing.eda import *

# %% [markdown]
# <div class='status' style='background-color: #f5c244; color: white; padding-top: 2px; padding-bottom: 2px; padding-left: 7px; padding-right: 7px; border-radius: 6px; font-family: Arial, sans-serif; font-size: 18px; display: inline-block; text-align: center; box-shadow: 0px 3px 4px rgba(0, 0, 0, 0.2);'><b>Loading</b> dataset</div>

# %%
data = pd.read_csv("../ai_medreview/data/data.csv")
data.head(10)
# Out:
#                   time     rating  \
# 0  2024-01-01 10:51:00  Very good
# 1  2024-01-01 15:20:00  Very good
# 2  2024-01-01 17:47:00  Very good
# 3  2024-01-02 07:58:00       Good
# 4  2024-01-02 10:44:00  Very good
# 5  2024-01-03 12:55:00  Very good
# 6  2024-01-03 15:19:00  Very good
# 7  2024-01-03 16:08:00       Good
# 8  2024-01-03 21:23:00  Very good
# 9  2024-01-03 21:55:00  Very good
#
#                                            free_text do_better  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  PERSON was amazing kind and helpful The recept...       NaN
# 4                                                NaN       NaN
# 5                                                NaN       NaN
# 6                                                NaN       NaN
# 7                                                NaN       NaN
# 8                                                NaN       NaN
# 9                                                NaN       NaN
#
#                     surgery                  pcn sentiment_free_text  \
# 0  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# 1  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# 2       Earls-Court-Surgery  Brompton-Health-PCN             neutral
# 3  Scarsdale-Medical-Centre  Brompton-Health-PCN            positive
# 4  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# 5  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# 6  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# 7  Scarsdale-Medical-Centre  Brompton-Health-PCN             neutral
# 8       Earls-Court-Surgery  Brompton-Health-PCN             neutral
# 9       Earls-Court-Surgery  Brompton-Health-PCN             neutral
#
#    sentiment_score_free_text sentiment_do_better  sentiment_score_do_better  \
# 0                   0.000000             neutral                        0.0
# 1                   0.000000             neutral                        0.0
# 2                   0.000000             neutral                        0.0
# 3                   0.937987             neutral                        0.0
# 4                   0.000000             neutral                        0.0
# 5                   0.000000             neutral                        0.0
# 6                   0.000000             neutral                        0.0
# 7                   0.000000             neutral                        0.0
# 8                   0.000000             neutral                        0.0
# 9                   0.000000             neutral                        0.0
#
#    free_text_len  do_better_len  rating_score              feedback_labels  \
# 0            4.0              0           5.0                          NaN
# 1            5.0              0           5.0                          NaN
# 2            2.0              2           5.0                          NaN
# 3           23.0              0           4.0  Reception Staff Interaction
# 4            1.0              0           5.0                          NaN
# 5            2.0              0           5.0                          NaN
# 6            4.0              0           5.0                          NaN
# 7            3.0              0           4.0                          NaN
# 8            0.0              0           5.0                          NaN
# 9            3.0              0           5.0                          NaN
#
#   improvement_labels submission_id respondent-id emotion_free_text  \
# 0                NaN       mannual        upload               NaN
# 1                NaN       mannual        upload               NaN
# 2                NaN           NaN           NaN               NaN
# 3                NaN       mannual        upload        admiration
# 4                NaN       mannual        upload               NaN
# 5                NaN       mannual        upload               NaN
# 6                NaN       mannual        upload               NaN
# 7                NaN       mannual        upload               NaN
# 8                NaN           NaN           NaN               NaN
# 9                NaN           NaN           NaN               NaN
#
#   emotion_do_better free_text_PER do_better_PER  campaing_id  logic  \
# 0               NaN           NaN           NaN          NaN    NaN
# 1               NaN           NaN           NaN          NaN    NaN
# 2               NaN           NaN           NaN          NaN    NaN
# 3               NaN    ['Denise']           NaN          NaN    NaN
# 4               NaN           NaN           NaN          NaN    NaN
# 5               NaN           NaN           NaN          NaN    NaN
# 6               NaN           NaN           NaN          NaN    NaN
# 7               NaN           NaN           NaN          NaN    NaN
# 8               NaN           NaN           NaN          NaN    NaN
# 9               NaN           NaN           NaN          NaN    NaN
#
#    campaign_rating  campaign_freetext  \
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3              NaN                NaN
# 4              NaN                NaN
# 5              NaN                NaN
# 6              NaN                NaN
# 7              NaN                NaN
# 8              NaN                NaN
# 9              NaN                NaN
#
#                                         free_text_qa do_better_qa
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3  {'score': 0.034968744963407516, 'start': 36, '...          NaN
# 4                                                NaN          NaN
# 5                                                NaN          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8                                                NaN          NaN
# 9                                                NaN          NaN

# %%
data.shape
# Out:
# (8010, 27)
