# %% [markdown]
# # Top2vec

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import sketch

# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv('../friendsfamilytest/data/data.csv')
data.head(2)
# Out:
#                   time            rating  \
# 0  2023-07-13 15:28:00  Extremely likely
# 1  2023-07-13 15:29:00  Extremely likely
#
#                                            free_text do_better  \
# 0  very friendly caring staff treated me with res...       NaN
# 1                            so good so confidential       NaN
#
#                surgery sentiment_free_text  sentiment_score_free_text  \
# 0  Earls Court Surgery            positive                   0.866406
# 1  Earls Court Surgery            positive                   0.925523
#
#   sentiment_do_better  sentiment_score_do_better  free_text_len  \
# 0             neutral                        0.0             13
# 1             neutral                        0.0              4
#
#    do_better_len  rating_score                      feedback_labels  \
# 0              3           5.0         Overall Patient Satisfaction
# 1              0           5.0  Patient Privacy and Confidentiality
#
#   improvement_labels
# ...

# %%
feedback = data.copy()
imp = data.copy()

feedback = data[['time', 'free_text']]
imp = data[['time', 'do_better']]

# %%
feedback
# Out:
#                      time                                          free_text
# 0     2023-07-13 15:28:00  very friendly caring staff treated me with res...
# 1     2023-07-13 15:29:00                            so good so confidential
# 2     2023-07-13 15:29:00  the doctor was very understanding and very kno...
# 3     2023-07-13 15:30:00                            dr e was extremely nice
# 4     2023-07-13 15:31:00  i was spoken to politely on the phone and a te...
# ...                   ...                                                ...
# 3759  2024-03-26 12:44:40                  the admin reasonably professional
# 3760  2024-03-26 14:20:19                                                NaN
# 3761  2024-03-26 17:28:02                                                NaN
# 3762  2024-03-26 17:40:49     every gp treated me was knowledgeable friendly
# 3763  2024-03-26 19:27:02                                                NaN
#
# [3764 rows x 2 columns]

# %%
imp.dropna(subset='do_better', inplace=True)
# Out:
# /var/folders/zk/h05bglw168z9vq1c9b862q480000gn/T/ipykernel_1033/48145250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imp.dropna(subset='do_better', inplace=True)

# %%
imp.columns = ['time','text']

# %%
feedback.dropna(subset='free_text', inplace=True)
# Out:
# /var/folders/zk/h05bglw168z9vq1c9b862q480000gn/T/ipykernel_1033/3679189428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feedback.dropna(subset='free_text', inplace=True)

# %%
feedback.columns = ['time','text']

# %%
df_merged = pd.concat([feedback, imp], ignore_index=True)

# %%
time_list = df_merged['time'].to_list()

# %%
text_list = df_merged['text'].to_list()

# %%
text_list
# Out:
# ['very friendly caring staff treated me with respect and listened to my problem',
#  'so good so confidential',
#  'the doctor was very understanding and very knowledgeable',
#  'dr e was extremely nice',
#  'i was spoken to politely on the phone and a telephone appointment arranged with my doctor which due to a mistake on a locked phone i wasn t able to answer but i was called back twice to complete my assessment of my health worry',
#  'very professional and very kind i feel comfortable when i attend my appointment there',
#  'faster appointment treatment',
#  'love the practice',
#  'the nurse miss a was absolutely amazing understanding kind fun thorough careful she is the best',
#  'i have been with surgery for considerable years and was well looked after by dr param hoping the work ethic continues apart that good service good location etc',
#  'efficient friendly staff',
#  'because the staff are very helpful',
#  'nurse a is really helpful and look after us',
# ...

# %%
from top2vec import Top2Vec

model = Top2Vec(documents=text_list, speed="learn", workers=8)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 3
#       1 from top2vec import Top2Vec
# ----> 3 model = Top2Vec(documents=text_list, speed="learn", workers=8)
#
# File ~/.pyenv/versions/friends2/lib/python3.10/site-packages/top2vec/Top2Vec.py:608, in Top2Vec.__init__(self, documents, min_count, topic_merge_delta, ngram_vocab, ngram_vocab_args, embedding_model, embedding_model_path, embedding_batch_size, split_documents, document_chunker, chunk_length, max_num_chunks, chunk_overlap_ratio, chunk_len_coverage_ratio, sentencizer, speed, use_corpus_file, document_ids, keep_documents, workers, tokenizer, use_embedding_model_tokenizer, umap_args, gpu_umap, hdbscan_args, gpu_hdbscan, index_topics, verbose)
#     605 self.embed = None
#     606 self.embedding_model = embedding_model
# --> 608 self._check_import_status()
# ...
