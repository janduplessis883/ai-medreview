# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/janduplessis/code/janduplessis883/ai-medreview/ai_medreview/data/data_v2.csv')

# %%
data[:100].to_csv('/Users/janduplessis/code/janduplessis883/ai-medreview/ai_medreview/data/sample.csv')
